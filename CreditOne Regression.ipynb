# %%
import numpy as np
import pandas as pd
import scipy
from math import sqrt
import matplotlib.pyplot as plt

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import linear_model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import train_test_split

# %%
rawData = pd.read_csv('default of credit card clients.csv')
rawData .head(3)
# Out:
#    LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university  Married   24      2      2     -1     -1
# 1     120000  female  university   Single   26     -1      2      0      0
# 2      90000  female  university   Single   34      0      0      0      0
#
#    BILL_AMT1  ...  graduate school  high school  other  university  Divorced  \
# 0       3913  ...                0            0      0           1         0
# 1       2682  ...                0            0      0           1         0
# 2      29239  ...                0            0      0           1         0
#
#    Married Other  default  loanAmount  StagesAdulthood
# 0        1     0        1      Tier 1      Young Adult
# 1        0     0        1      Tier 1      Young Adult
# 2        0     0        0      Tier 1      Young Adult
#
# [3 rows x 28 columns]

# %%
rawData .drop('loanAmount', inplace=True, axis=1)
rawData .head(1)
# Out:
#    LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university  Married   24      2      2     -1     -1
#
#    BILL_AMT1  ...  female  graduate school  high school  other  university  \
# 0       3913  ...       1                0            0      0           1
#
#    Divorced Married  Other  default  StagesAdulthood
# 0         0       1      0        1      Young Adult
#
# [1 rows x 27 columns]

# %%
rawData .drop('StagesAdulthood', inplace=True, axis=1)
rawData .head(1)
# Out:
#    LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university  Married   24      2      2     -1     -1
#
#    BILL_AMT1  ...  default_Payment  female  graduate school  high school  \
# 0       3913  ...          default       1                0            0
#
#    other  university Divorced  Married  Other  default
# 0      0           1        0        1      0        1
#
# [1 rows x 26 columns]

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LIMIT_BAL        30000 non-null  int64
#  1   SEX              30000 non-null  object
#  2   EDUCATION        30000 non-null  object
#  3   MARRIAGE         30000 non-null  object
#  4   AGE              30000 non-null  int64
#  5   PAY_0            30000 non-null  int64
#  6   PAY_2            30000 non-null  int64
#  7   PAY_3            30000 non-null  int64
#  8   PAY_4            30000 non-null  int64
#  9   BILL_AMT1        30000 non-null  int64
#  10  PAY_AMT1         30000 non-null  int64
#  11  PAY_AMT2         30000 non-null  int64
#  12  PAY_AMT3         30000 non-null  int64
#  13  PAY_AMT4         30000 non-null  int64
#  14  PAY_AMT5         30000 non-null  int64
#  15  PAY_AMT6         30000 non-null  int64
#  16  default_Payment  30000 non-null  object
# ...

# %%
rawData.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'BILL_AMT1', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default_Payment', 'female',
#        'graduate school', 'high school', 'other', 'university', 'Divorced',
#        'Married', 'Other', 'default'],
#       dtype='object')

# %%
X = rawData.iloc[0:,0:25]
print('Summary of feature sample')
X.head()
# Out:
# Summary of feature sample
#    LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university  Married   24      2      2     -1     -1
# 1     120000  female  university   Single   26     -1      2      0      0
# 2      90000  female  university   Single   34      0      0      0      0
# 3      50000  female  university  Married   37      0      0      0      0
# 4      50000    male  university  Married   57     -1      0     -1      0
#
#    BILL_AMT1  ...  PAY_AMT6  default_Payment  female  graduate school  \
# 0       3913  ...         0          default       1                0
# 1       2682  ...      2000          default       1                0
# 2      29239  ...      5000      not default       1                0
# 3      46990  ...      1000      not default       1                0
# 4       8617  ...       679      not default       0                0
#
#    high school  other university  Divorced  Married  Other
# ...

# %%
y = rawData.iloc[0:,25:]
y.head()
# Out:
#    default
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %%
#train, test = train_test_split(rawData, test_size=0.2, random_state=42, shuffle=True)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.to_csv('train_path.csv')
X_test.to_csv('test_path.csv')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(n_jobs=10)

# %%
print(y)

# %%
#algosClass = []
#algosClass .append(('Random Forest Regressor', RandomForestRegressor()))

# %%
#from sklearn 
#X, y = make_regression(n_features=4, n_informative=2,
                       #random_state=0, shuffle=False)
#regr = RandomForestRegressor(max_depth=2, random_state=0)
#regr.fit(X, y)

#print(regr.predict())

# %%
algosClass.append(('Linear Regression', LinearRegression()))

# %%
regr = linear_model.LinearRegression()

x = np.asanyarray(X_train[['PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4']])
y = np.asanyarray(X_train[['default']])

regr.fit (x, y)
print ('Coefficients: ', regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 5>()
#       1 regr = linear_model.LinearRegression()
#       3 x = np.asanyarray(X_train[['PAY_0', 'PAY_2',
#       4        'PAY_3', 'PAY_4']])
# ----> 5 y = np.asanyarray(X_train[['default']])
#       7 regr.fit (x, y)
#       8 print ('Coefficients: ', regr.coef_)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
# ...

# %%
y_= regr.predict(test[['PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4']])
x = np.asanyarray(test[['PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4']])
y = np.asanyarray(test[['default']])

print("Residual sum of squares: %.2f"% np.mean((y_ - y) ** 2))
print('Variance score: %.2f' % regr.score(x, y))

# %%
plt.style.use('fivethirtyeight')

# %%
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train,
            color = "green", s = 10, label = 'Train data')

# %%
algosClass.append(('Support Vector Regression', SVR()))
