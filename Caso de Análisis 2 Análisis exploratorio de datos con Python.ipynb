# %% [markdown]
# *Se realiza la importacion de las bibiotecas pandas, seaborn and matplotlib
# *se hace el uso de plt.style.use('bmh') el cual define el estilo de la hoja a usar

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %% [markdown]
# *se crea la variable df la cual hara la lectura y carga del set de datos train.csv
# con df.head() se solicita mostrar los primeros records del set de datos

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# *Con df.info  podemos obtener un resumen del set de datos como cantidad de columnas y el tipo de variable con la que
# estaremos trabajando, tipo int, float u object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# *se define el subset de datos df2 apartir del original en el que indicamos que nos devuelva la cantidad de columnas en el dataframe y que lo divida entre la longitud del data frame siempre que sea mayor o igual que 0.3.
# Al usar del df2['Id'] pedimos a python eliminar ddel df2 la columna ID, el imprime el mensaje solicitado y con end agregamos un string al final de dicho mensaje

# %%
# df.count() does not include NaN values
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]
del df2['Id']
print("List of dropped columns:", end=" ")
for c in df.columns:
    if c not in df2.columns:
        print(c, end=", ")
print('\n')
df = df2
# Out:
# List of dropped columns: Id, Alley, PoolQC, Fence, MiscFeature,

# %% [markdown]
# *se imprime la columna SalesPrice del set de datos df con los calculos estandard para promedio, media, min, max etc
# *se activa la figura con plt.figure y se define el tamano del grafico a crear
# *se utiliza de la biblioteca seaborn el grafico distplot que es basicamente un histograma con una linea encima, utilizamos
# la columna SalePrice, le asignamos el color verde al grafico, dividimos los valores en rangos de 100, finalmente con
# hist_kws asignamos el nivel de transparencia de nuestro grafico

# %%
print(df['SalePrice'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# C:\Users\danie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# *se crea la variable list la cual contiene la recien creada lista de tipos de valores dentro del data set

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('O'), dtype('float64')]

# %% [markdown]
# *se crea la variable df_num la cual  por medio de df.select_dtypes le pide crear un subset de datos de las columnas del DF
# basado en el tipo de la columna, en este caso se buscan las columnas con valores numericos de tipo float e int
# *se imprimen primeros los valores por medio del df_num.head()

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# *se crean histogramas a partir de recien creado subset de datos al cual se les asigna un tamaño de 16x20 conlas etiqueta X y
# Y de tamaño 8

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'MSSubClass'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>,
#         <AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'OverallCond'}>,
#         <AxesSubplot:title={'center':'YearBuilt'}>],
#        [<AxesSubplot:title={'center':'YearRemodAdd'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF2'}>,
#         <AxesSubplot:title={'center':'BsmtUnfSF'}>,
#         <AxesSubplot:title={'center':'TotalBsmtSF'}>],
#        [<AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>,
#         <AxesSubplot:title={'center':'LowQualFinSF'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>,
#         <AxesSubplot:title={'center':'BsmtFullBath'}>,
#         <AxesSubplot:title={'center':'BsmtHalfBath'}>],
# ...

# %% [markdown]
# *se crea la variable df_num_corr la cual utilizaremos para realizar nuestra matriz de correlacion basandonos en SalePrice
# para nuestra correlacion y removiendo el ultimo valor en esa columna
# *se crea la lista golden_features_list en la cual le pedimos el valor absoluto de los valores en nuestra variable df_num_corr siempre y cuando sean mayores que 0.5, asi mismo le pedimos que no acomode los resultados en orden ascendente
# *se imprime el mensaje "There is {} strongly correlated values with SalePrice:\n{}", pidiendole que nos muestre el numero de resultados encontrados dentro de la lista golden_features_list

# %%
df_num_corr = df_num.corr()['SalePrice'][:-1] 
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 10 strongly correlated values with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# *se define un rango apartir del indice 0 para los valores almacenados en df_num.columns en incrementos de 5
# *se crea un grafico que visualiza la distribucion de varias variables (y axis) en relacion a una sola variable (x axis) que en este ejemplo seria SalePrice

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num, x_vars=df_num.columns[i:i+5], y_vars=['SalePrice'])

# %% [markdown]
# *se realiza la importacion del modulo integrado de Python Operador el cual nos permitira realizar funciones matematicas
# *se crea una lista vacia llamada individual_features_df
# *se crea un rango partiendo del indice cero dentro del subset de datos df_num y con el -1 eliminamos el ultimo valor el cual seria SalePrice
# *se crea un subset de datos llamdo tmpDf a partir de df_num en el que pedimos el numero de valores en SalesPrice
# *creamos el subset de datos en el que pedimos los valores siempre que sean diferentes a 0
# y estos se incorporan al df indivuadual_features_df
#
# Se crean correlaciones a partir de la Columna SalePrice y se imprimen de menor a mayor

# %%
import operator

individual_features_df = []
for i in range(0, len(df_num.columns) - 1): 
    tmpDf = df_num[[df_num.columns[i], 'SalePrice']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['SalePrice'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
#    KitchenAbvGr: -0.1392006921778576
#        HalfBath: -0.08439171127179902
#      MSSubClass: -0.08428413512659509
#     OverallCond: -0.07785589404867797
#          YrSold: -0.028922585168736813
#    BsmtHalfBath: -0.02883456718548182
#        PoolArea: -0.014091521506356765
#    BsmtFullBath: 0.011439163340408606
#          MoSold: 0.046432245223819446
#       3SsnPorch: 0.06393243256889088
#     OpenPorchSF: 0.08645298857147718
#         MiscVal: 0.08896338917298921
#      Fireplaces: 0.12166058421363891
#       BsmtUnfSF: 0.16926100049514173
#    BedroomAbvGr: 0.18093669310848806
#      WoodDeckSF: 0.1937060123752066
#      BsmtFinSF2: 0.19895609430836594
#   EnclosedPorch: 0.24127883630117497
#     ScreenPorch: 0.2554300795487841
#         LotArea: 0.2638433538714051
#    LowQualFinSF: 0.30007501655501323
#     LotFrontage: 0.35179909657067737
#      MasVnrArea: 0.43409021975689227
#      BsmtFinSF1: 0.47169042652357296
#     GarageYrBlt: 0.4863616774878596
# ...

# %%
golden_features_list = [key for key, value in all_correlations if abs(value) >= 0.5]
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 11 strongly correlated values with SalePrice:
# ['YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd', 'FullBath', '1stFlrSF', 'GarageArea', 'TotalBsmtSF', 'GarageCars', '2ndFlrSF', 'GrLivArea', 'OverallQual']

# %% [markdown]
# *Se crea una matriz de correlacion en la que se elimina la columna SalePrice y se toman las columnas a partir de la posicion 1, asi comenzando desde MS Sub Class
# *se le asigna un tamaño de 12x10 a la figura
# *y se utiliza el diseño de seaborn de mapa de calor para nuestra representacion de la matriz. en esta establecemos los valores  de la correlacion que queremos resaltar, ya sea si la correlaccion es igual o mayor a -0.4 o a 0.5. Con cmap definimos la escala de colores a utilizar (viridis, magma, turbo etc). Se define un valor minimo y un valor maximo. Se define el grosor de las lineas en nuestro grafico. annot=True quiere decir que si el Vmin y Vmax estan definidos imprimame el valor, si noestan definidos pues entonces no mostrara el numero. annot_kws define el tamaño del texto que aparezca dentro del mapa. square=True define la figura que queremos que tenga el mapa

# %%
corr = df_num.drop('SalePrice', axis=1).corr() 
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %% [markdown]
# *Se crea una lista  llamada quantitative_features_list la cual contiene los nombre de las columnas del data set
# *se crea un subset de datos apartir de la recien creada lista
# *se imprime el nuevo set de datos

# %%
quantitative_features_list = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', '1stFlrSF',
    '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 
    'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']
df_quantitative_values = df[quantitative_features_list]
df_quantitative_values.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  TotalBsmtSF  \
# 0         65.0     8450       196.0         706           0          856
# 1         80.0     9600         0.0         978           0         1262
# 2         68.0    11250       162.0         486           0          920
# 3         60.0     9550         0.0         216           0          756
# 4         84.0    14260       350.0         655           0         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  ...  GarageCars  GarageArea  \
# 0       856       854             0       1710  ...           2         548
# 1      1262         0             0       1262  ...           2         460
# 2       920       866             0       1786  ...           2         608
# 3       961       756             0       1717  ...           3         642
# 4      1145      1053             0       2198  ...           3         836
#
# ...

# %% [markdown]
# *creamos la lista features_to_analyse a partir de la lista quantitative_features_list en la que se encuentren los valores de la lista golden_features_list
# *a la lista golden_features_list vamos a agregarle SalePrice y vamos a imprimir la lista que acabamos de crear

# %%
features_to_analyse = [x for x in quantitative_features_list if x in golden_features_list]
features_to_analyse.append('SalePrice')
features_to_analyse
# Out:
# ['TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %% [markdown]
# *Fig, ax es una abreviatura de fig = plt.figure() y ax = plt.subplot(). Por medio de esta funcion creamos un grafico a partir de uno existente, donde le pedimos que nos de la longitud lista features_to_analyse, y que lo divida entre tres y que adicionalmente redondee los valores.Le pedimos que despliegue 3 graficos en la misma linea de tamaño 18x12
#
# *Pedimos enumerar al index dentro de fig.axes siempre que se cumpla la siguiente condicion:
# si index es menor a la longitud de features_to_analyse entonces devuelvanos el ultimo valor. E imprimalo en un grafico de tipo replot de Seaborn donde X es igual a la informacion en features_to_analyse y Y equivale a SalePrice, se define de donde se esta tomando la informacion

# %%
fig, ax = plt.subplots(round(len(features_to_analyse) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse) - 1:
        sns.regplot(x=features_to_analyse[i],y='SalePrice', data=df[features_to_analyse], ax=ax)

# %% [markdown]
# Se crea la lista categorical_features donde le pedimos devolver los valores de quantitative_features_list excepto el ultimo item de la lista, pedimos con df.columns.tolist() que nos de el nombre de las columnas de data frame en formato de lista siempre que a no este en la lista quantitative_features_list o en df.columns.tolist/.
#
# Se crea un subset dde datos a partir de los valores recien obtenidos y se imprimen.

# %%
# quantitative_features_list[:-1] as the last column is SalePrice and we want to keep it
categorical_features = [a for a in quantitative_features_list[:-1] + df.columns.tolist() if (a not in quantitative_features_list[:-1]) or (a not in df.columns.tolist())]
df_categ = df[categorical_features]
df_categ.head()
# Out:
#    MSSubClass MSZoning Street LotShape LandContour Utilities LotConfig  \
# 0          60       RL   Pave      Reg         Lvl    AllPub    Inside
# 1          20       RL   Pave      Reg         Lvl    AllPub       FR2
# 2          60       RL   Pave      IR1         Lvl    AllPub    Inside
# 3          70       RL   Pave      IR1         Lvl    AllPub    Corner
# 4          60       RL   Pave      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood Condition1  ... GarageYrBlt GarageFinish GarageQual  \
# 0       Gtl      CollgCr       Norm  ...      2003.0          RFn         TA
# 1       Gtl      Veenker      Feedr  ...      1976.0          RFn         TA
# 2       Gtl      CollgCr       Norm  ...      2001.0          RFn         TA
# 3       Gtl      Crawfor       Norm  ...      1998.0          Unf         TA
# 4       Gtl      NoRidge       Norm  ...      2000.0          RFn         TA
#
#    GarageCond  PavedDrive  MoSold  YrSold SaleType SaleCondition SalePrice
# ...

# %% [markdown]
# se crea un subset dde ddatos en el que se selecciona todas aquellas columnas que no sean de tipo numerico y se imprimen en una lista

# %%
df_not_num = df_categ.select_dtypes(include = ['O'])
print('There is {} non numerical features including:\n{}'.format(len(df_not_num.columns), df_not_num.columns.tolist()))
# Out:
# There is 39 non numerical features including:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# Definimos la figura y tamaño a utilizar. Definimos la variable ax la cual contiene el grafico tipo box plot de Seaborn, donde X es igual a BsmtExposure y Y es SalePrice , del subset de datos llamado df_categ.
# por medio de plt.setp se definen los colores y el grosor de las lineas de nuestro grafico
# plt.xticks(rotation=45) nos indica el grado de inclinacion de los titulos en X

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='BsmtExposure', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'No'), Text(1, 0, 'Gd'), Text(2, 0, 'Mn'), Text(3, 0, 'Av')])

# %% [markdown]
# *creamos una figura de tamaño 12x6
# *se crea la variable ax la cual contiene el diseño boxplot de seaborn donde X es Sales Condition y Y es Saleprice y data nos indica de donde proviene la informacion
# *

# %%
plt.figure(figsize = (12, 6))
ax = sns.boxplot(x='SaleCondition', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Normal'),
#   Text(1, 0, 'Abnorml'),
#   Text(2, 0, 'Partial'),
#   Text(3, 0, 'AdjLand'),
#   Text(4, 0, 'Alloca'),
#   Text(5, 0, 'Family')])

# %% [markdown]
# Se crean graficos a partir del subset de datos df_not_num donde se le asigna un tamano de 12x30, y 3 graficos por fila.

# %%
fig, axes = plt.subplots(round(len(df_not_num.columns) / 3), 3, figsize=(12, 30))

for i, ax in enumerate(fig.axes):
    if i < len(df_not_num.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
        sns.countplot(x=df_not_num.columns[i], alpha=0.7, data=df_not_num, ax=ax)

fig.tight_layout()
# Out:
# <ipython-input-21-44f9464776ab>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
# <ipython-input-21-44f9464776ab>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
# <ipython-input-21-44f9464776ab>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
# <ipython-input-21-44f9464776ab>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
# <ipython-input-21-44f9464776ab>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
# ...
